# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
df_tran = gpd.read_file('./data/output/tranportation_amend.geojson')

# %%
df_tran.head()
# Out:
#   subclass   footway  crossing  curbramps  length             description  \
# 0  footway  crossing  unmarked        1.0   21.13     Crossing at 1ST AVE
# 1  footway  crossing    marked        1.0   20.46   Crossing at 1ST AVE S
# 2  footway  crossing    marked        1.0   20.09  Crossing at YESLER WAY
# 3  footway  crossing    marked        1.0   15.85  Crossing at YESLER WAY
# 4  footway  crossing    marked        1.0   20.40     Crossing at 1ST AVE
#
#    incline surface  width  layer df_num pb_num h_num dof_num  elevator  \
# 0      NaN    None    NaN    NaN   None   None  None    None       NaN
# 1      NaN    None    NaN    NaN   None   None  None    None       NaN
# 2      NaN    None    NaN    NaN   None   None  None    None       NaN
# 3      NaN    None    NaN    NaN   None   None  None    None       NaN
# 4      NaN    None    NaN    NaN   None   None  None    None       NaN
#
#    indoor opening_hours                                           geometry
# ...

# %%
df_2.to_file('./data/raw_data/temp.geojson',driver="GeoJSON")

# %%
df_crossing.head()
# Out:
#    Unnamed: 0  ID  curbramps  length             description  incline  \
# 0           0   1          1   21.13     Crossing at 1ST AVE      NaN
# 1           1   2          1   20.46   Crossing at 1ST AVE S      NaN
# 2           2   3          1   20.09  Crossing at YESLER WAY      NaN
# 3           3   4          1   15.85  Crossing at YESLER WAY      NaN
# 4           4   5          1   20.40     Crossing at 1ST AVE      NaN
#
#    surface  width  layer  elevator  indoor  opening_hours  \
# 0      NaN    NaN    NaN       NaN     NaN            NaN
# 1      NaN    NaN    NaN       NaN     NaN            NaN
# 2      NaN    NaN    NaN       NaN     NaN            NaN
# 3      NaN    NaN    NaN       NaN     NaN            NaN
# 4      NaN    NaN    NaN       NaN     NaN            NaN
#
#                  v_coordinates                u_coordinates
# 0  (-122.33431401,47.60182781)  (-122.33404254,47.60177833)
# 1  (-122.33404306,47.60163572)   (-122.3343147,47.60164708)
# ...
