# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
df_crossing = pd.read_csv('./data/raw_data/crossings.csv')
df_sw = pd.read_csv('./data/raw_data/sidewalks.csv')

# %%
df_sw.head()
# Out:
#    Unnamed: 0  ID  curbramps  length                     description  incline  \
# 0           0   1        NaN   68.25        Sidewalk W of 39TH AVE S    0.008
# 1           1   2        NaN  188.02       Sidewalk W of 49TH AVE NE    0.029
# 2           2   3        NaN    6.29  Sidewalk SW of WOODLAWN AVE NE    0.000
# 3           3   4        NaN   71.95  Sidewalk SW of WOODLAWN AVE NE    0.010
# 4           4   5        NaN   76.76     Sidewalk NE of BOYLSTON AVE    0.013
#
#     surface  width  layer  elevator  indoor  opening_hours  \
# 0  concrete   1.52      0       NaN     NaN            NaN
# 1  concrete   1.83      0       NaN     NaN            NaN
# 2  concrete   1.83      0       NaN     NaN            NaN
# 3  concrete   1.83      0       NaN     NaN            NaN
# 4  concrete   2.44      0       NaN     NaN            NaN
#
#                  v_coordinates                u_coordinates
# 0  (-122.28352768,47.55128815)  (-122.28354108,47.55190212)
# ...

# %%
df_crossing.head()
# Out:
#    Unnamed: 0  ID  curbramps  length             description  incline  \
# 0           0   1          1   21.13     Crossing at 1ST AVE      NaN
# 1           1   2          1   20.46   Crossing at 1ST AVE S      NaN
# 2           2   3          1   20.09  Crossing at YESLER WAY      NaN
# 3           3   4          1   15.85  Crossing at YESLER WAY      NaN
# 4           4   5          1   20.40     Crossing at 1ST AVE      NaN
#
#    surface  width  layer  elevator  indoor  opening_hours  \
# 0      NaN    NaN    NaN       NaN     NaN            NaN
# 1      NaN    NaN    NaN       NaN     NaN            NaN
# 2      NaN    NaN    NaN       NaN     NaN            NaN
# 3      NaN    NaN    NaN       NaN     NaN            NaN
# 4      NaN    NaN    NaN       NaN     NaN            NaN
#
#                  v_coordinates                u_coordinates
# 0  (-122.33431401,47.60182781)  (-122.33404254,47.60177833)
# 1  (-122.33404306,47.60163572)   (-122.3343147,47.60164708)
# ...
