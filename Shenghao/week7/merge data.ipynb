# %%
import geopandas as gpd
import pandas as pd

# %%
dir1 = 'C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\park_only_boundary1.geojson'
dir2 = 'C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\sidewalk_trail.geojson'
st_df = gpd.read_file(dir2)
pb_df = gpd.read_file(dir1)

# %%
st_df.head()
# Out:
#   condition  forward graph_layer  incline  layer             length      pkey  \
# 0      FAIR      1.0    sidewalk    -15.0    0.0  28.55368477083827  314716.0
# 1      FAIR      1.0    sidewalk      0.0    0.0  6.256332034174294  314716.0
# 2      GOOD      0.0    sidewalk    -40.0    0.0  67.39927884547073  307254.0
# 3      GOOD      1.0    sidewalk    -90.0    0.0  129.6843287406617  326146.0
# 4      GOOD      1.0    sidewalk   -191.0    0.0  86.02870971671874  312705.0
#
#   side    street_name  streets_pkey  \
# 0    N   S BENNETT ST       19496.0
# 1    N   S BENNETT ST       19496.0
# 2    E     8TH AVE NE        8328.0
# 3    S  SW STEVENS ST       22859.0
# 4   NE   E TERRACE ST       14841.0
#
#                          ...                           width amwoid  \
# 0                        ...                           1.524   None
# 1                        ...                           1.524   None
# ...

# %%
pb_df.head(2)
# Out:
#                         name shape_area   parksbnd_a   pma shape_len  \
# 0       12TH AVE SQUARE PARK          0  7316.172948  4467         0
# 1  6TH AVENUE NW POCKET PARK          0  9006.612569  3158         0
#
#                                             geometry
# 0  (POLYGON ((-122.3162480182179 47.6071438821052...
# 1  (POLYGON ((-122.3634527097912 47.6843669164890...

# %%
pb_df.drop(['shape_area', 'shape_len'], axis=1, inplace=True)
pb_df.rename(columns={'parksbnd_a': 'park_area'}, inplace=True)
pb_df['graph_layer'] = 'park_boundary'
pb_df.head(2)
# Out:
#                         name    park_area   pma  \
# 0       12TH AVE SQUARE PARK  7316.172948  4467
# 1  6TH AVENUE NW POCKET PARK  9006.612569  3158
#
#                                             geometry    graph_layer
# 0  (POLYGON ((-122.3162480182179 47.6071438821052...  park_boundary
# 1  (POLYGON ((-122.3634527097912 47.6843669164890...  park_boundary

# %%
combine_df = pd.concat([pb_df, st_df], ignore_index=True)
combine_df.head()
# Out:
# C:\Users\xiegudong45\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#   amwoid condition  forward  \
# 0    NaN       NaN      NaN
# 1    NaN       NaN      NaN
# 2    NaN       NaN      NaN
# 3    NaN       NaN      NaN
# 4    NaN       NaN      NaN
#
#                                             geometry grade_perc grade_type  \
# 0  (POLYGON ((-122.3162480182179 47.6071438821052...        NaN        NaN
# 1  (POLYGON ((-122.3634527097912 47.6843669164890...        NaN        NaN
# 2  (POLYGON ((-122.348654185465 47.65023051082457...        NaN        NaN
# 3  (POLYGON ((-122.2984079350166 47.7206142912442...        NaN        NaN
# ...

# %%
combine_df.to_file('C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\sidewalk_trail_boundary.geojson', driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-70008693d547> in <module>
# ----> 1 combine_df.to_file('C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\sidewalk_trail_boundary.geojson', driver='GeoJSON')
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     363         """
#     364         from geopandas.io.file import to_file
# --> 365         to_file(self, filename, driver, schema, **kwargs)
#     366
#     367     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in to_file(df, filename, driver, schema, **kwargs)
#      58     """
#      59     if schema is None:
# ---> 60         schema = infer_schema(df)
#      61     filename = os.path.abspath(os.path.expanduser(filename))
# ...
