# %%
import geopandas as gpd
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\week6'

# %%
trail = 'C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\Trails.geojson'
trail_df = gpd.read_file(trail)
trail_df.head()
# Out:
#                      pma_name           gis_edt_dt      amwoid  \
# 0           ME-KWA-MOOKS PARK  2017-02-08T00:00:00  TRAIL-5522
# 1  GENESEE PARK AND PLAYFIELD  2017-02-08T00:00:00  TRAIL-2701
# 2           ME-KWA-MOOKS PARK  2017-02-08T00:00:00  TRAIL-5503
# 3       SCHMITZ PRESERVE PARK  2017-02-22T00:00:00  TRAIL-6706
# 4      LICORICE FERN NA ON TC  2017-02-08T00:00:00  TRAIL-3001
#
#                                   field_note grade_perc grade_type  \
# 0                    gone, consumed by brush          5    Gradual
# 1                                          -          3       Flat
# 2                         exposed tree roots          9      Steep
# 3  has culvert ; storm water erosion, damage          5    Gradual
# 4                                          -          3       Flat
#
#      shape_leng pictures    gis_length  condition  \
# 0   43.14959805        -   43.14968435  Overgrown
# 1  353.63145955        -  353.63216681       Good
# ...

# %% [markdown]
# ## Desribe each column ????

# %%
trail_df.drop(['pictures','gis_edt_dt', 'date_time', 'shape_leng', 
               'canopy', 'shape_len', 'district', 'trail_num', 'shape_le_1', 'field_note'],axis=1,inplace=True)
trail_df.head()
# Out:
#                      pma_name      amwoid grade_perc grade_type    gis_length  \
# 0           ME-KWA-MOOKS PARK  TRAIL-5522          5    Gradual   43.14968435
# 1  GENESEE PARK AND PLAYFIELD  TRAIL-2701          3       Flat  353.63216681
# 2           ME-KWA-MOOKS PARK  TRAIL-5503          9      Steep  193.38282237
# 3       SCHMITZ PRESERVE PARK  TRAIL-6706          5    Gradual  209.86138603
# 4      LICORICE FERN NA ON TC  TRAIL-3001          3       Flat   130.7621017
#
#    condition pmaid surface_ty trail_clas width trail_id  \
# 0  Overgrown   473       Soil          2     1   473-11
# 1       Good   409     Gravel          1     5   409-28
# 2       Good   473       Soil          1     2   473-15
# 3       Worn   465     Gravel          1     4   465-14
# 4       Poor  4479       Soil          2     1   4479-7
#
#                                             geometry
# 0  (LINESTRING (-122.4026159955043 47.56118839598...
# ...

# %%
trail_df.columns
# Out:
# Index(['pma_name', 'amwoid', 'grade_perc', 'grade_type', 'gis_length',
#        'condition', 'pmaid', 'surface_ty', 'trail_clas', 'width', 'trail_id',
#        'geometry'],
#       dtype='object')

# %%
trail_df['graph_layer'] = 'trail'
trail_df.rename(columns={'surface_ty': 'surface', 'gis_length': 'length'}, inplace=True)
trail_df['surface'] = trail_df.astype(str).surface.str.lower()
trail_df.head()
# Out:
#                      pma_name      amwoid grade_perc grade_type        length  \
# 0           ME-KWA-MOOKS PARK  TRAIL-5522          5    Gradual   43.14968435
# 1  GENESEE PARK AND PLAYFIELD  TRAIL-2701          3       Flat  353.63216681
# 2           ME-KWA-MOOKS PARK  TRAIL-5503          9      Steep  193.38282237
# 3       SCHMITZ PRESERVE PARK  TRAIL-6706          5    Gradual  209.86138603
# 4      LICORICE FERN NA ON TC  TRAIL-3001          3       Flat   130.7621017
#
#    condition pmaid surface trail_clas width trail_id  \
# 0  Overgrown   473    soil          2     1   473-11
# 1       Good   409  gravel          1     5   409-28
# 2       Good   473    soil          1     2   473-15
# 3       Worn   465  gravel          1     4   465-14
# 4       Poor  4479    soil          2     1   4479-7
#
#                                             geometry   type graph_layer
# 0  (LINESTRING (-122.4026159955043 47.56118839598...  trail       trail
# ...

# %%
sidewalk = 'C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\sidewalk_amend.geojson'
sidewalk_df = gpd.read_file(sidewalk)
sidewalk_df.head()
# Out:
#   condition  forward  incline  layer    pkey side    street_name  \
# 0      FAIR      1.0      -15      0  314716    N   S BENNETT ST
# 1      FAIR      1.0        0      0  314716    N   S BENNETT ST
# 2      GOOD      0.0      -40      0  307254    E     8TH AVE NE
# 3      GOOD      1.0      -90      0  326146    S  SW STEVENS ST
# 4      GOOD      1.0     -191      0  312705   NE   E TERRACE ST
#
#    streets_pkey   surface   width      length  \
# 0         19496  concrete  1.5240   28.553685
# 1         19496  concrete  1.5240    6.256332
# 2          8328  concrete  1.8288   67.399279
# 3         22859  concrete  1.8288  129.684329
# 4         14841  concrete  1.8288   86.028710
#
#                                             geometry
# 0  LINESTRING (-122.3109895837122 47.554803238548...
# 1  LINESTRING (-122.3110727362415 47.554803619255...
# 2  LINESTRING (-122.3202017666824 47.688878742907...
# 3  LINESTRING (-122.3980609246822 47.577509031485...
# ...

# %%
sidewalk_df['graph_layer'] = 'sidewalk'
sidewalk_df.head()
# Out:
#   condition  forward  incline  layer    pkey side    street_name  \
# 0      FAIR      1.0      -15      0  314716    N   S BENNETT ST
# 1      FAIR      1.0        0      0  314716    N   S BENNETT ST
# 2      GOOD      0.0      -40      0  307254    E     8TH AVE NE
# 3      GOOD      1.0      -90      0  326146    S  SW STEVENS ST
# 4      GOOD      1.0     -191      0  312705   NE   E TERRACE ST
#
#    streets_pkey   surface   width      length  \
# 0         19496  concrete  1.5240   28.553685
# 1         19496  concrete  1.5240    6.256332
# 2          8328  concrete  1.8288   67.399279
# 3         22859  concrete  1.8288  129.684329
# 4         14841  concrete  1.8288   86.028710
#
#                                             geometry graph_layer
# 0  LINESTRING (-122.3109895837122 47.554803238548...    sidewalk
# 1  LINESTRING (-122.3110727362415 47.554803619255...    sidewalk
# 2  LINESTRING (-122.3202017666824 47.688878742907...    sidewalk
# ...

# %%
combine_df = pd.concat([sidewalk_df, trail_df], ignore_index=True)
combine_df
# Out:
# C:\Users\xiegudong45\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#            amwoid  condition  forward  \
# 0             NaN       FAIR      1.0
# 1             NaN       FAIR      1.0
# 2             NaN       GOOD      0.0
# 3             NaN       GOOD      1.0
# 4             NaN       GOOD      1.0
# 5             NaN       GOOD      0.0
# 6             NaN       FAIR      0.0
# 7             NaN                 0.0
# 8             NaN       FAIR      0.0
# 9             NaN       GOOD      0.0
# 10            NaN       FAIR      0.0
# 11            NaN       FAIR      1.0
# 12            NaN       FAIR      0.0
# 13            NaN  EXCELLENT      0.0
# ...

# %%
combine_df.columns
# Out:
# Index(['amwoid', 'condition', 'forward', 'geometry', 'grade_perc',
#        'grade_type', 'incline', 'layer', 'length', 'pkey', 'pma_name', 'side',
#        'street_nam', 'streets_pk', 'surface', 'trail_clas', 'trail_id', 'type',
#        'width'],
#       dtype='object')

# %%
combine_df.to_file('C:\\Users\\xiegudong45\\Desktop\\CSE495\\City-scale-Analytics\\Shenghao\\data\\sidewalk_trail.geojson', driver='GeoJSON')
